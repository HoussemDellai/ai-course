# %% [markdown]
# # Chat with a Self-Hosted LLM Using Microsoft Agent Framework
#
# This notebook demonstrates how to use the **Microsoft Agent Framework** to build an AI agent that chats with a self-hosted Gemma 4 model running on Azure Container Apps (ACA) with vLLM.
#
# The Agent Framework's `OpenAIChatClient` connects to any OpenAI-compatible endpoint, including the vLLM server deployed in this project.

# %%
# %pip install agent-framework==1.0.1
# Out:
# Requirement already satisfied: agent-framework==1.0.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (1.0.1)
# Requirement already satisfied: agent-framework-core==1.0.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.1)
# Requirement already satisfied: typing-extensions<5,>=4.15.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.2.1)
# Requirement already satisfied: opentelemetry-api<2,>=1.39.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.39.0)
# Requirement already satisfied: mcp<2,>=1.24.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.26.0)
# Requirement already satisfied: agent-framework-a2a in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-ag-ui in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-azure-ai-search in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-azure-cosmos in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-anthropic in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-openai in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.1)
# Requirement already satisfied: agent-framework-claude in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-azurefunctions in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-bedrock in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-chatkit in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-copilotstudio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-declarative in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-devui in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260414)
# Requirement already satisfied: agent-framework-durabletask in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-foundry in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.1)
# Requirement already satisfied: agent-framework-foundry-local in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-github-copilot in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-lab in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b251024)
# Requirement already satisfied: agent-framework-mem0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-ollama in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-orchestrations in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-purview in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: agent-framework-redis in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b260409)
# Requirement already satisfied: anyio>=4.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.0.22)
# Requirement already satisfied: pywin32>=310 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.41.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api<2,>=1.39.0->agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2,>=1.39.0->agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core==1.0.1->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.41.5)
# Requirement already satisfied: idna>=2.8 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.5->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.11)
# Requirement already satisfied: certifi in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.30.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.0)
# Requirement already satisfied: click>=7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (8.3.1)
# Requirement already satisfied: colorama in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp<2,>=1.24.0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.4.6)
# Requirement already satisfied: a2a-sdk<0.3.24,>=0.3.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.3.23)
# Requirement already satisfied: google-api-core>=1.26.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.30.3)
# Requirement already satisfied: protobuf>=5.29.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (6.33.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.27.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.49.2)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.32.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.6.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.3.24,>=0.3.5->agent-framework-a2a->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.6.3)
# Requirement already satisfied: ag-ui-protocol==0.1.13 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.1.13)
# Requirement already satisfied: fastapi<0.133.1,>=0.115.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.133.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from fastapi<0.133.1,>=0.115.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.7.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (6.0.3)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]<0.42.0,>=0.30.0->agent-framework-ag-ui->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (15.0.1)
# Requirement already satisfied: anthropic<0.80.1,>=0.80.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-anthropic->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.80.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.18.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<0.80.1,>=0.80.0->agent-framework-anthropic->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.3.1)
# Requirement already satisfied: azure-search-documents<11.7.0b3,>=11.7.0b2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azure-ai-search->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (11.7.0b2)
# Requirement already satisfied: azure-core>=1.28.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-search-documents<11.7.0b3,>=11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.38.2)
# Requirement already satisfied: azure-common>=1.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-search-documents<11.7.0b3,>=11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-search-documents<11.7.0b3,>=11.7.0b2->agent-framework-azure-ai-search->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.7.2)
# Requirement already satisfied: azure-cosmos<5,>=4.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azure-cosmos->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.15.0)
# Requirement already satisfied: azure-functions<2,>=1.24.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.24.0)
# Requirement already satisfied: azure-functions-durable<2,>=1.3.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.5.0)
# Requirement already satisfied: werkzeug~=3.1.3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-functions<2,>=1.24.0->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.1.8)
# Requirement already satisfied: aiohttp>=3.13.3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.13.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.9.0.post0)
# Requirement already satisfied: furl>=2.1.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.1.4)
# Requirement already satisfied: opentelemetry-sdk>=1.32.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.39.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from werkzeug~=3.1.3->azure-functions<2,>=1.24.0->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.13.3->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.22.0)
# Requirement already satisfied: six>=1.8.0 in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from furl>=2.1.0->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.17.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from furl>=2.1.0->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.32.1->azure-functions-durable<2,>=1.3.1->agent-framework-azurefunctions->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.60b0)
# Requirement already satisfied: boto3<2.0.0,>=1.35.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-bedrock->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.42.89)
# Requirement already satisfied: botocore<2.0.0,>=1.35.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-bedrock->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.42.89)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from boto3<2.0.0,>=1.35.0->agent-framework-bedrock->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from boto3<2.0.0,>=1.35.0->agent-framework-bedrock->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.16.0)
# Requirement already satisfied: openai-chatkit<2.0.0,>=1.4.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.6.3)
# Requirement already satisfied: openai in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.32.0)
# Requirement already satisfied: openai-agents>=0.3.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.14.1)
# Requirement already satisfied: jinja2<4,>=3.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.1.6)
# Requirement already satisfied: griffelib<3,>=2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.0.2)
# Requirement already satisfied: types-requests<3,>=2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai-agents>=0.3.2->openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.33.0.20260408)
# Requirement already satisfied: tqdm>4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai->openai-chatkit<2.0.0,>=1.4.1->agent-framework-chatkit->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.67.3)
# Requirement already satisfied: claude-agent-sdk<0.1.49,>=0.1.36 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-claude->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.1.48)
# Requirement already satisfied: microsoft-agents-copilotstudio-client<0.3.2,>=0.3.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-copilotstudio->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.3.1)
# Requirement already satisfied: microsoft-agents-hosting-core==0.3.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from microsoft-agents-copilotstudio-client<0.3.2,>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.3.1)
# Requirement already satisfied: microsoft-agents-activity==0.3.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from microsoft-agents-hosting-core==0.3.1->microsoft-agents-copilotstudio-client<0.3.2,>=0.3.1->agent-framework-copilotstudio->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.3.1)
# Requirement already satisfied: powerfx<0.0.35,>=0.0.32 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-declarative->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.0.34)
# Requirement already satisfied: pythonnet==3.0.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from powerfx<0.0.35,>=0.0.32->agent-framework-declarative->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.0.5)
# Requirement already satisfied: clr_loader<0.3.0,>=0.2.7 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pythonnet==3.0.5->powerfx<0.0.35,>=0.0.32->agent-framework-declarative->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.2.10)
# Requirement already satisfied: durabletask<2,>=1.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.4.0)
# Requirement already satisfied: durabletask-azuremanaged<2,>=1.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.4.0)
# Requirement already satisfied: grpcio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from durabletask<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.78.1)
# Requirement already satisfied: asyncio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from durabletask<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.0.0)
# Requirement already satisfied: packaging in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from durabletask<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (26.0)
# Requirement already satisfied: azure-identity>=1.19.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from durabletask-azuremanaged<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.25.2)
# Requirement already satisfied: msal>=1.31.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-identity>=1.19.0->durabletask-azuremanaged<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-identity>=1.19.0->durabletask-azuremanaged<2,>=1.3.0->agent-framework-durabletask->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.3.1)
# Requirement already satisfied: azure-ai-inference<1.0.0b10,>=1.0.0b9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-foundry->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.0b9)
# Requirement already satisfied: azure-ai-projects<3.0,>=2.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-foundry->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.0.1)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-projects<3.0,>=2.0.0->agent-framework-foundry->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (12.28.0)
# Requirement already satisfied: foundry-local-sdk<0.5.2,>=0.5.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-foundry-local->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.5.1)
# Requirement already satisfied: github-copilot-sdk<=0.2.1,>=0.2.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-github-copilot->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.2.1)
# Requirement already satisfied: mem0ai<2,>=1.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.0.11)
# Requirement already satisfied: posthog>=3.5.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (7.12.0)
# Requirement already satisfied: pytz>=2024.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2026.1.post1)
# Requirement already satisfied: qdrant-client>=1.9.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.17.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.0.49)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from posthog>=3.5.0->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.2.1)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (2.4.2)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (4.1.0)
# Requirement already satisfied: greenlet>=1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy>=2.0.31->mem0ai<2,>=1.0.0->agent-framework-mem0->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.4.0)
# Requirement already satisfied: ollama<0.5.4,>=0.5.3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-ollama->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.5.3)
# Requirement already satisfied: redis<7.2.1,>=6.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (7.1.1)
# Requirement already satisfied: redisvl<0.16,>=0.11.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-redis->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.15.0)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (1.8.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (0.5.4)
# Requirement already satisfied: python-ulid>=3.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from redisvl<0.16,>=0.11.0->agent-framework-redis->agent-framework-core[all]==1.0.1->agent-framework==1.0.1) (9.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Get the LLM Endpoint
#
# Retrieve the FQDN of the Gemma 4 model deployed on ACA from the Terraform output.

# %%
aca_gemma4_31b_it_a100_fqdn = ! terraform output -raw aca_gemma4_31b_it_a100_fqdn
aca_gemma4_31b_it_a100_fqdn = aca_gemma4_31b_it_a100_fqdn.n
print("LLM Endpoint:", aca_gemma4_31b_it_a100_fqdn)
# Out:
# LLM Endpoint: gemma-4-31b-it-a100.icyocean-d166d91d.swedencentral.azurecontainerapps.io

# %% [markdown]
# ## 1. Simple Agent — Single Turn
#
# Create an agent backed by the self-hosted Gemma 4 model via `OpenAIChatClient` pointing at the vLLM OpenAI-compatible endpoint.

# %%
from agent_framework import Agent
from agent_framework.openai import OpenAIChatClient

client = OpenAIChatClient(
    base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1",
    api_key="EMPTY",
    model="google/gemma-4-31B-it",
)

async with Agent(
    client=client,
    instructions="You are a helpful AI assistant. Be concise and informative.",
) as agent:
    result = await agent.run("What is Azure Container Apps?")
    print(result.text)
# Out:
# **Azure Container Apps (ACA)** is a fully managed, serverless container service designed for building and deploying modern, microservices-based applications.
#
# It abstracts away the complexity of managing underlying infrastructure (like Kubernetes), allowing developers to focus on writing code rather than configuring clusters.
#
# ### Key Features
# *   **Serverless Scaling:** It automatically scales your containers based on HTTP traffic or events (KEDA). It can even **scale to zero** when not in use to save costs.
# *   **Built on Open Source:** It is powered by **Kubernetes**, **KEDA** (event-driven autoscaling), **Dapr** (distributed application runtime), and **Envoy** (proxy).
# *   **Simplified Networking:** It includes built-in ingress (HTTP/TCP) and traffic splitting, making it easy to perform **Blue-Green** or **Canary** deployments.
# *   **Microservices Support:** Through the integration of **Dapr**, it simplifies common microservice challenges like state management, service-to-service communication, and pub/sub messaging.
#
# ### When to use it vs. other Azure services:
#
# | Service | Use Case | Management Level |
# | :--- | :--- | :--- |
# | **Azure Container Apps** | Microservices, APIs, and event-driven apps that need autoscaling without K8s complexity. | **Serverless** (Lowest) |
# | **Azure Container Instances (ACI)** | Simple, isolated containers for short-lived tasks or simple apps. | **Container-as-a-Service** |
# | **Azure Kubernetes Service (AKS)** | Full control over the cluster, complex networking, and high customization. | **Managed Kubernetes** (Highest) |
#
# ### Summary
# Use **Azure Container Apps** if you want the power of Kubernetes (scaling, orchestration, microservices) but want a "hands-off" experience where Azure handles the infrastructure, scaling, and patching.

# %% [markdown]
# ## 2. Streaming Response
#
# Use `stream=True` for a token-by-token streaming experience, which is the recommended pattern for production-grade apps.

# %%
from agent_framework import Agent
from agent_framework.openai import OpenAIChatClient

client = OpenAIChatClient(
    base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1",
    api_key="EMPTY",
    model="google/gemma-4-31B-it",
)

async with Agent(
    client=client,
    instructions="You are a helpful AI assistant. Be concise and informative.",
) as agent:
    print("Agent: ", end="", flush=True)

    stream = agent.run("Explain Kubernetes in 3 sentences.", stream=True)
    
    async for chunk in stream:
        if chunk.text:
            print(chunk.text, end="", flush=True)
    print()
    await stream.get_final_response()  # finalize the stream
# Out:
# Agent: Kubernetes is an open-source orchestration platform designed to automate the deployment, scaling, and management of containerized applications. It ensures high availability by monitoring containers and automatically restarting or replacing those that fail. By distributing workloads across a cluster of machines, it optimizes resource usage and allows applications to scale seamlessly based on demand.

# %% [markdown]
# ## 3. Agent with Tool Calling
#
# Enhance the agent with custom Python functions as tools. The Agent Framework automatically handles the tool-calling loop with the LLM.

# %%
from typing import Annotated
from random import randint
from pydantic import Field
from agent_framework import Agent, tool
from agent_framework.openai import OpenAIChatClient


# NOTE: approval_mode="never_require" is for sample brevity.
# Use "always_require" in production for user confirmation before tool execution.
@tool(approval_mode="never_require")
def get_weather(
    location: Annotated[str, Field(description="The location to get the weather for.")],
) -> str:
    """Get the weather for a given location."""
    conditions = ["sunny", "cloudy", "rainy", "stormy"]
    return f"The weather in {location} is {conditions[randint(0, 3)]} with a high of {randint(10, 30)}°C."

# def get_time(
#     timezone: Annotated[str, "The timezone, e.g. 'UTC', 'CET', 'PST'."],
# ) -> str:
#     """Get the current time in a given timezone."""
#     from datetime import datetime
#     return f"The current time in {timezone} is {datetime.now().strftime('%H:%M:%S')} (simulated)."


agent = Agent(
    client=OpenAIChatClient(
        base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1",
        api_key="EMPTY",
        model="google/gemma-4-31B-it",
    ),
    name="WeatherAgent",
    instructions="You are a helpful assistant that can provide weather and restaurant information.",
    # tools=[get_weather],
)

response = await agent.run("What's the weather like in Seattle?")
print(f"Agent: {response.text}")

# print("Agent: ", end="", flush=True)

# stream = await agent.run("What's the weather in Amsterdam and what are today's specials?", stream=True)
# async for chunk in stream:
#     if chunk.text:
#         print(chunk.text, end="", flush=True)
# print()
# await stream.get_final_response()

# %%
from agent_framework import Agent, ChatOptions, MCPStreamableHTTPTool
from agent_framework.openai import OpenAIChatClient

# client = OpenAIChatClient(
#     base_url=f"http://127.0.0.1:11434/v1/", 
#     model="gemma4:31b",
#     api_key="EMPTY"
# )

# client = OpenAIChatClient(
#     base_url="https://foundry-555.openai.azure.com/openai/v1",
#     model="gpt-5.2",
#     api_key="7lDCTqHKRZDATNxBKqZk3QKh8EoFlRVvMIYGeJds0fWad81JYiLAJQQJ99CDACfhMk5XJ3w3AAAAACOGlf3w"
# )

client = OpenAIChatClient(
    base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1",
    model="google/gemma-4-31B-it",
    api_key="EMPTY"
)

async with (
    MCPStreamableHTTPTool(
        name="Microsoft Learn MCP",
        url="https://learn.microsoft.com/api/mcp",
    ) as mcp_server,
    Agent(
        client=client,
        name="DocsAgent",
        instructions="You help with Microsoft documentation questions.",
    ) as agent,
):
    response = await agent.run(
        "How to create an Azure storage account using az cli?",
        tools=mcp_server,
        options=ChatOptions(max_tokens=1024, temperature=0.9),
    )

    print(f"Agent: {response.text}")
# Out:
# Agent: Use `az storage account create`. A minimal end-to-end example:
#
# ```bash
# # sign in (skip if already signed in, e.g., in Cloud Shell)
# az login
#
# # create a resource group
# az group create \
#   --name storage-resource-group \
#   --location eastus
#
# # create a StorageV2 (general-purpose v2) storage account
# # (account name must be globally unique, 3-24 lowercase letters/numbers)
# az storage account create \
#   --name <account-name> \
#   --resource-group storage-resource-group \
#   --location eastus \
#   --sku Standard_RAGRS \
#   --kind StorageV2 \
#   --min-tls-version TLS1_2 \
#   --allow-blob-public-access false
# ```
#
# Verify:
#
# ```bash
# az storage account show -g storage-resource-group -n <account-name>
# ```
#
# Docs: https://learn.microsoft.com/azure/storage/common/storage-account-create#create-a-storage-account and CLI reference: https://learn.microsoft.com/cli/azure/storage/account?view=azure-cli-latest#az-storage-account-create

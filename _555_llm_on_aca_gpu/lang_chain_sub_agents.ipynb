# %% [markdown]
# # LangChain Multi-Agent System with Subagents pattern
#
# In the subagents architecture, a central main agent (often referred to as a supervisor) coordinates subagents by calling them as tools. The main agent decides which subagent to invoke, what input to provide, and how to combine results. Subagents are stateless—they don’t remember past interactions, with all conversation memory maintained by the main agent. This provides context isolation: each subagent invocation works in a clean context window, preventing context bloat in the main conversation.
#
# ## Prerequisites
#
# Deploy the infrastructure using the Terraform files in this directory (see `lang_chain.ipynb` for details):
# ```bash
# terraform init
# terraform apply -auto-approve
# ```

# %% [markdown]
# ## 1. Install Dependencies

# %%
# %pip install langchain langgraph langchain-openai langchain-mcp-adapters langgraph-supervisor
# Out:
# Requirement already satisfied: langchain in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (1.2.15)
# Requirement already satisfied: langgraph in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (1.1.8)
# Requirement already satisfied: langchain-openai in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (1.1.15)
# Requirement already satisfied: langchain-mcp-adapters in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (0.2.2)
# Requirement already satisfied: langgraph-supervisor in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (0.0.31)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (2.32.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: mcp>=1.9.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-mcp-adapters) (1.26.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.0.22)
# Requirement already satisfied: pywin32>=310 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.52.1)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.41.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings>=2.5.2->mcp>=1.9.2->langchain-mcp-adapters) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: colorama in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Get the LLM and MCP Server Endpoints
#
# Retrieve the FQDNs of the Gemma 4 model and the MCP web search server deployed on ACA from Terraform output.

# %%
aca_gemma4_31b_it_a100_fqdn = ! terraform output -raw aca_gemma4_31b_it_a100_fqdn
aca_gemma4_31b_it_a100_fqdn = aca_gemma4_31b_it_a100_fqdn.n
print("LLM Endpoint:", aca_gemma4_31b_it_a100_fqdn)

aca_mcp_server_fqdn = ! terraform output -raw aca_mcp_server_fqdn
aca_mcp_server_fqdn = aca_mcp_server_fqdn.n
print("MCP Server Endpoint:", aca_mcp_server_fqdn)
# Out:
# LLM Endpoint: gemma-4-31b-it-a100.gentlemushroom-793350b5.swedencentral.azurecontainerapps.io
# MCP Server Endpoint: mcp-server.gentlemushroom-793350b5.swedencentral.azurecontainerapps.io

# %% [markdown]
# ## 3. Create the LLM Model
#
# Create a `ChatOpenAI` model pointing at the vLLM OpenAI-compatible endpoint.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

model = ChatOpenAI(
    base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1",
    api_key="EMPTY",
    model="google/gemma-4-31B-it",
    streaming=True,
    max_completion_tokens=512
)

# %% [markdown]
# Test the model with a simple prompt to ensure it’s working correctly.

# %%
response = model.stream([HumanMessage(content="What is Azure Container Apps?")])

for chunk in response:
    print(chunk.content, end="", flush=True)
# Out:
# **Azure Container Apps (ACA)** is a fully managed, serverless platform designed for deploying and scaling applications and microservices.
#
# In simplest terms: **It is a middle ground between the simplicity of Azure App Service (which hosts a single app) and the complexity of Azure Kubernetes Service (AKS) (which gives you full control over a cluster).**
#
# Under the hood, it is built on **Kubernetes**, but Azure hides all the Kubernetes complexity (nodes, pods, ingress controllers, and YAML configurations) from you.
#
# ---
#
# ### Core Features
#
# #### 1. Serverless Scaling (KEDA)
# One of the most powerful features of ACA is its ability to scale based on HTTP traffic or events.
# *   **Scale to Zero:** If no one is using your app, ACA can scale the number of running containers down to zero, meaning you stop paying for compute.
# *   **Event-Driven Scaling:** Using KEDA (Kubernetes Event-driven Autoscaling), it can scale based on things like the number of messages in an Azure Service Bus queue or a Kafka topic.
#
# #### 2. Built-in Dapr Integration
# ACA has native support for **Dapr (Distributed Application Runtime)**. Dapr is an open-source framework that makes it easier to build microservices by providing "building blocks" for:
# *   **State Management:** Saving data without worrying about the specific database API.
# *   **Pub/Sub:** Sending messages between services.
# *   **Service-to-Service Invocation:** Ensuring services can find and talk to each other securely.
#
# #### 3. Integrated Traffic Management (Envoy)
# ACA includes a built-in ingress controller based on Envoy. This allows you to:
# *   **Split Traffic:** You can send 90% of traffic to "Version 1" and 10% to "Version 2" (Canary deployments).
# *   **Blue-Green Deployments:** Swap versions instantly once the new one is tested.
#
# #### 4. Simplified Networking
# You don't have to configure complex load balancers or networking rules. When you deploy a Container App, Azure automatically provides a URL and manages the HTTPS termination.
#
# ---
#
# ### When should you use Azure Container Apps?
#
# | Use Case | Recommended Service | Why? |
# | :--- | :--- | :--- |
# | **Simple Web App / API** | **Azure App Service** | Easier if you just have one monolithic

# %% [markdown]
# ## Deep Research Agent
#
# The [Deep Research](https://docs.langchain.com/oss/python/deepagents/deep-research) pattern uses the `deepagents` package to build a multi-step web research agent that:
#
# 1. **Plans** research by decomposing the question into focused tasks (using a TODO list)
# 2. **Delegates** focused research tasks to sub-agents with isolated context
# 3. **Assesses** search results and plans next steps as information is gathered
# 4. **Synthesizes** findings with proper citations into a comprehensive final report
#
# ### Architecture
#
# ```
# User ──▶ Deep Research Agent (orchestrator)
#               │
#               ├──▶ research-agent (subagent 1) ──▶ web search tool
#               ├──▶ research-agent (subagent 2) ──▶ web search tool
#               └──▶ research-agent (subagent 3) ──▶ web search tool
#               │
#               └──▶ Final synthesized report with citations
# ```
#
# ### Install Deep Agents

# %%
# %pip install deepagents langchain-mcp-adapters markdownify
# Out:
# Requirement already satisfied: deepagents in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (0.5.5)
# Requirement already satisfied: langchain-mcp-adapters in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (0.2.2)
# Collecting markdownify
#   Downloading markdownify-1.2.2-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from deepagents) (1.3.2)
# Requirement already satisfied: langsmith>=0.7.35 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from deepagents) (0.8.0)
# Requirement already satisfied: langchain<2.0.0,>=1.2.15 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from deepagents) (1.2.15)
# Requirement already satisfied: langchain-anthropic<2.0.0,>=1.4.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from deepagents) (1.4.2)
# Requirement already satisfied: langchain-google-genai<5.0.0,>=4.2.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from deepagents) (4.2.2)
# Requirement already satisfied: wcmatch in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from deepagents) (10.1)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain<2.0.0,>=1.2.15->deepagents) (1.1.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain<2.0.0,>=1.2.15->deepagents) (2.12.5)
# Requirement already satisfied: anthropic<1.0.0,>=0.96.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-anthropic<2.0.0,>=1.4.2->deepagents) (0.97.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (3.11)
# Requirement already satisfied: certifi in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.96.0->langchain-anthropic<2.0.0,>=1.4.2->deepagents) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->deepagents) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->deepagents) (0.0.14)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.3.2->deepagents) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->deepagents) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->deepagents) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->deepagents) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->deepagents) (3.1.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai<5.0.0,>=4.2.2->deepagents) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.65.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai<5.0.0,>=4.2.2->deepagents) (1.74.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (2.49.2)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (2.32.5)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (15.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (46.0.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.2.15->deepagents) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.2.15->deepagents) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.2.15->deepagents) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.2.15->deepagents) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.2.15->deepagents) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain<2.0.0,>=1.2.15->deepagents) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langsmith>=0.7.35->deepagents) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langsmith>=0.7.35->deepagents) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.2.15->deepagents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.2.15->deepagents) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.2.15->deepagents) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (2.6.3)
# Requirement already satisfied: mcp>=1.9.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from langchain-mcp-adapters) (1.26.0)
# Collecting beautifulsoup4<5,>=4.9 (from markdownify)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: six<2,>=1.15 in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from markdownify) (1.17.0)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5,>=4.9->markdownify)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (3.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.2->langchain-mcp-adapters) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.0.22)
# Requirement already satisfied: pywin32>=310 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.52.1)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.41.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.30.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain-google-genai<5.0.0,>=4.2.2->deepagents) (0.6.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings>=2.5.2->mcp>=1.9.2->langchain-mcp-adapters) (1.2.1)
# Requirement already satisfied: click>=7.0 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters) (8.3.1)
# Requirement already satisfied: colorama in c:\users\azureuser\appdata\roaming\python\python313\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters) (0.4.6)
# Requirement already satisfied: bracex>=2.1.1 in c:\users\azureuser\appdata\local\programs\python\python313\lib\site-packages (from wcmatch->deepagents) (2.6)
# Downloading markdownify-1.2.2-py3-none-any.whl (15 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4, markdownify
#
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [markdownify]
#    ---------------------------------------- 3/3 [markdownify]
#
# Successfully installed beautifulsoup4-4.14.3 markdownify-1.2.2 soupsieve-2.8.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Set up the Web Search Tool as MCP Tool

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain.agents import create_agent

# Connect to the remote MCP server over Streamable HTTP
mcp_client_web_search = MultiServerMCPClient(
    {
        "web-search": {
            "url": f"http://{aca_mcp_server_fqdn}/mcp",
            "transport": "http",
        }
    }
)

# Discover tools exposed by the MCP server
mcp_tools_web_search = await mcp_client_web_search.get_tools()
print("MCP tools discovered:", [t.name for t in mcp_tools_web_search])

# Create an agent with the self-hosted LLM + MCP tools
agent_with_mcp = create_agent(model, mcp_tools_web_search)
# Out:
# MCP tools discovered: ['search', 'fetchLinuxDoArticle', 'fetchCsdnArticle', 'fetchGithubReadme', 'fetchWebContent', 'fetchJuejinArticle']

# %% [markdown]
# ### Streaming with MCP Tools
#
# Stream the agent's step-by-step reasoning as it decides to call the remote MCP web search tool and synthesizes the results.

# %%
async for step in agent_with_mcp.astream(
    {"messages": [HumanMessage(content="What is the current price for Microsoft stock ?")]},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the current stock price for Microsoft ?
# ================================== Ai Message ==================================
# Tool Calls:
#   search (chatcmpl-tool-a89ee2f1aec341d1)
#  Call ID: chatcmpl-tool-a89ee2f1aec341d1
#   Args:
#     query: current stock price for Microsoft MSFT
# ================================= Tool Message =================================
# Name: search
#
# [{'type': 'text', 'text': '{\n  "query": "current stock price for Microsoft MSFT",\n  "engines": [\n    "duckduckgo"\n  ],\n  "totalResults": 10,\n  "results": [\n    {\n      "title": "MSFT Stock Price | Microsoft Corp. Stock Quote (U.S.: Nasdaq ...",\n      "url": "https://www.marketwatch.com/investing/stock/MSFT",\n      "description": "<b>MSFT</b> | Complete <b>Microsoft</b> Corp. <b>stock</b> news by MarketWatch. View real-time <b>stock</b> <b>prices</b> and <b>stock</b> quotes for a full financial overview.",\n      "source": "www.marketwatch.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft Corp (MSFT) Stock Price &amp; News - Google Finance",\n      "url": "https://www.google.com/finance/quote/MSFT%3ANASDAQ",\n      "description": "The company&#x27;s 1986 initial public offering and subsequent rise in its share <b>price</b> created three billionaires and an estimated 12,000 millionaires among <b>Microsoft</b> employees.",\n      "source": "www.google.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft Corporation (MSFT) Stock Price, News, Quote &amp; History - Yahoo ...",\n      "url": "https://finance.yahoo.com/quote/MSFT/",\n      "description": "Find the latest <b>Microsoft</b> Corporation (<b>MSFT</b>) <b>stock</b> quote, history, news and other vital information to help you with your <b>stock</b> trading and investing.",\n      "source": "finance.yahoo.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft (MSFT) Stock Price, News &amp; Analysis - MarketBeat",\n      "url": "https://www.marketbeat.com/stocks/NASDAQ/MSFT/",\n      "description": "Should You Buy or Sell <b>Microsoft</b> <b>Stock</b>? Get The Latest <b>MSFT</b> <b>Stock</b> Analysis, <b>Price</b> Target, Dividend Info, Headlines, and Short Interest at MarketBeat.",\n      "source": "www.marketbeat.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft Stock Price Today | NASDAQ: MSFT Live - Investing.com",\n      "url": "https://www.investing.com/equities/microsoft-corp",\n      "description": "View today&#x27;s <b>Microsoft</b> Corporation <b>stock</b> <b>price</b> and latest <b>MSFT</b> news and analysis. Create real-time notifications to follow any changes in the live <b>stock</b> <b>price</b>.",\n      "source": "www.investing.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft (MSFT) Stock Price &amp; Overview",\n      "url": "https://stockanalysis.com/stocks/msft/",\n      "description": "A detailed overview of <b>Microsoft</b> Corporation (<b>MSFT</b>) <b>stock</b>, including real-time <b>price</b>, chart, key statistics, news, and more.",\n      "source": "stockanalysis.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft Stock Price Quote - NASDAQ: MSFT - Morningstar",\n      "url": "https://www.morningstar.com/stocks/xnas/msft/quote",\n      "description": "Get the latest <b>Microsoft</b> <b>stock</b> <b>price</b> NASDAQ: <b>MSFT</b> <b>stock</b> rating and detailed information including <b>MSFT</b> news, historical charts and real-time <b>prices</b>.",\n      "source": "www.morningstar.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "MSFT: Microsoft Corp Stock Price Quote - NASDAQ GS - Bloomberg",\n      "url": "https://www.bloomberg.com/quote/MSFT%3AUS",\n      "description": "<b>Stock</b> analysis for <b>Microsoft</b> Corp (MSFT:NASDAQ GS) including <b>stock</b> <b>price</b>, <b>stock</b> chart, company news, key statistics, fundamentals and company profile.",\n      "source": "www.bloomberg.com",\n      "engine": "duckduckgo"\n    },\n    {\n      "title": "Microsoft (MSFT) Stock Price, Quote, News &amp; History | Benzinga",\n      "url": "https://www.benzinga.com/quote/msft",\n      "description": "Get real-time <b>Microsoft</b> (<b>MSFT</b>) <b>stock</b> <b>price</b>, charts, news, and analyst ratings on Benzinga. Access forecasts, historical data, and expert insights ...
# ================================== Ai Message ==================================
# Tool Calls:
#   fetchWebContent (chatcmpl-tool-b8225b87f8db8b6f)
#  Call ID: chatcmpl-tool-b8225b87f8db8b6f
#   Args:
#     url: https://www.google.com/finance/quote/MSFT%3ANASDAQ
# ================================= Tool Message =================================
# Name: fetchWebContent
#
# [{'type': 'text', 'text': '{\n  "url": "https://www.google.com/finance/quote/MSFT%3ANASDAQ",\n  "finalUrl": "https://www.google.com/finance/quote/MSFT:NASDAQ?ucbcb=1",\n  "contentType": "text/html; charset=utf-8",\n  "title": "微軟（MSFT）股价和资讯 - Google 财经",\n  "retrievalMethod": "request",\n  "truncated": false,\n  "content": "首页MSFT • NASDAQ微軟关注分享$407.78盘后：$408.65(0.21%)+0.87已休市： 4月30日, GMT-4 19:59:19 · USD · NASDAQ · 免责声明1 天5 天1 个月6 个月YTD1 年5 年最大范围insights重要事件“重要活动”部分会在价格出现较大变动的当天显示相关新闻报道重要事件“重要活动”部分会在价格出现较大变动的当天显示相关新闻报道重要事件arrow_forward_ios“重要活动”部分会在价格出现较大变动的当天显示相关新闻报道无数据closesearch比较苹果$271.35AAPL0.44%亚马逊$265.06AMZN0.77%Invesco QQQ Trust, Series 1$667.74QQQ0.93%网飞$93.61NFLX1.62%博通$417.43AVGO2.95%英伟达$199.57NVDA4.63%洛克希德·马丁$517.97LMT1.60%特斯拉汽车$381.63TSLA2.37%reddit公司$147.23RDDT0.35%SPDR標準普爾500指數ETF$718.66SPY0.99%相关资讯Yahoo Finance19小时前Citi Turn More Positive on Microsoft Corporation (MSFT) Ahead of Fiscal Q3 ResultsTipRanks11小时前“Win Back Fans”: Microsoft Stock (NASDAQ:MSFT) Plunges as Microsoft Admits It Is LosingThe Motley Fool1天前Microsoft vs. Amazon: Comparing Consistent Revenue Growth in Tech GiantsMarketBeat1天前Microsoft (NASDAQ:MSFT) Issues Earnings ResultsBenzinga10小时前What\'s Going On With Microsoft Stock Thursday? - Microsoft (NASDAQ:MSFT)24/7 Wall St.10小时前Microsoft Falls 5% Despite Q3 Beat: Why $190 Billion in AI Spending Has Investors Worried财务信息损益表\ue316\ue313季度年度2026年3月2025年12月2025年9月2025年6月2025年3月收入净收入(USD)2026年3月info第 Q3 2026 季度财务报表截止日期为 2026/3/31。年同比变化收入通过销售与公司主要业务相关的商品或服务而产生的总收入828.86亿18.30%经营支出指通过正常运营产生的总费用——净收入公司在一段时间内获得的净利润（扣除经营费用、税费和利息）——净利润率以在收入中所占百分比的形式衡量产生的净收入或利润。——每股收益表示用公司利润除以公司在外流通的普通股得出的结果。4.2723.41%息税折旧摊销前利润税前息前折旧前摊销前利润是衡量公司总体财务业绩的指标，且可在某些情况下作为净收入的替代项——有效税率公司用于缴纳税费的收入的百分比——资产负债表\ue316\ue313季度年度2026年3月2025年12月2025年9月2025年6月2025年3月总资产负债总额(USD)2026年3月info第 Q3 2026 季度财务报表截止日期为 2026/3/31。年同比变化现金及短期投资流动性相对较高且期限在 3 个月至 1 年之间的投资——总资产公司拥有的资产总额——负债总额公司所欠的债务总额——权益总额从公司的总资产中减去总负债所得的值——发行在外的股份截至财务文件披露的最近日期，发行在外的普通股总数——市净率一种比率，用于确定一家公司的市值是否符合其资产减去债务和优先股的价值——资产回报率一种财务比率，反映了一家公司资产的盈利能力——资本回报率公司的回报高出其用于支付债务和权益资本的平均成本19.48%—现金流\ue316\ue313季度年度2026年3月2025年12月2025年9月2025年6月2025年3月现金净变动(USD)2026年3月info第 Q3 2026 季度财务报表截止日期为 2026/3/31。年同比变化净收入公司在一段时间内获得的净利润（扣除经营费用、税费和利息）——来自运营的现金核心业务活动使用或产生的现金净额——投资现金购买资产等投资活动使用或产生的现金净额——融资现金在股息支付和贷款等融资活动中使用或产生的现金净额——现金净变动在一个会计期间内，公司的现金余额所增减的金额——自由现金流企业在履行债务和未偿付款等财务义务后拥有的现金金额——股票对企业的部分所有权以及对企业资产和利润的份额的主张权，具体取决于持有的股票数量在美国上市的证券在NASDAQ上市总部位于美国总部位于美国华盛顿雷德蒙德昨日收盘价上次收盘价$424.46当日价格范围上一交易日最高价和最低价之间的价差$398.01 - $414.42年度波幅过去 52 周内最高价和最低价之间的价差$356.28 - $555.45市值一种将公司股票价格乘以已发行股票总数的估值方法。3.03万亿 USD平均交易量过去 30 天中每天平均交易的股票数量3288.07万市盈率当前股价与过去十二个月每股收益的比率，反映了股价与其他股票相比是高还是低25.51股息率年度股息与当前股价的比率，用于估算股票的股息回报0.89%主要交易所该证券的上市交易所NASDAQ简介\ue316\ue313微软是源自美国的跨国科技公司，于1975年由比尔·盖茨与保罗·艾伦创立，总部位于美国华盛顿州的雷德蒙德，与亚马逊、苹果、谷歌、Meta并行为五大科技巨头，同时为北美4大云服务提供者之一。其中为研发、制造、授权及提供广泛的电脑软件服务为主要业务，最为著名且畅销的产品是Microsoft Windows操作系统及Microsoft Office办公软件，其它子公司如Xbox游戏业务等也都十分的著名。\\n公司成立初期, 主要为Altair 8800发展和销售BASIC解释器，在1980年代中期借着MS-DOS在家用电脑操作系统市场上获取长足进步，后来出现的Windows使得微软逐渐统治了家用桌面电脑操作系统市场。同时微软也开始扩大业务，进军其它行业和市场，创建了MSN网站，在电脑硬件市场上，微软商标及Xbox游戏机、Zune和MSN TV家庭娱乐设备也在不同的年份出现在市场上。微软于1986年首次公开募股，此后不断走高的股价为微软缔造了四位亿万富翁和12,000位百万富翁。\\n随着公司的强大，微软也受到越来越多的批评和责备，数十年来从未间断。拒绝交易和捆绑销售等做法招致垄断和不正当竞争的诉讼。美国司法部和欧盟委员会根据反托拉斯法均对微软做出过不利裁定。\\n截至2015年，尽管在Android和iOS的竞争下，微软已经失去了绝大部分移动设备的系统占比，但在IBM PC兼容操作系统市场和办公软件套装市场仍占据主导地位。该公司还为台式机，笔记型电脑，标签，小工具和服务器生产各种其他消费者和企业软件，包括互联网搜索，数字服务市场，混合现实，云计算和软件开发。\\n史蒂夫鲍尔默于2000年取代盖茨担任首席执行官，后来设想了“设备和服务”战略。随着微软在2008年收购Danger 公司，于2012年6月首次进入个人电脑生产市场，随着微软Surface 系列平板电脑的推出，以及随后通过收购诺基亚设备形成微软移动和服务部门。自萨蒂亚纳德拉于2014年接任首席执行官以来，该公司业务已多元化，除了原先的Windows 、 Office 和游戏主机业务，还发展Surface 系列和云服务，并更积极的参与开源，例如在2016年8月18日，宣布开源PowerShell，并在Windows 业务、 Office 业务和Xbox 业务之外新增对Linux平台的支持，发展 WSL，开源 Windows Terminal，收购 GitHub，.NET 框架 开源并跨平台，开源 VS Code，加强发展Microsoft Azure 平台，Office 产品支持多平台。\\n2018年，微软曾一度超越苹果公司，成为全球最有价值的上市公司。在2019年4月，微软达到了1万亿美元的市值，成为仅次于苹果公司第二家股价市值超过1万亿美元的美国上市公司。 WikipediaCEO萨蒂亚·纳德拉成立时间1975年4月4日总部华盛顿雷德蒙德美国网站microsoft.com员工数量228,000"\n}', 'id': 'lc_9674a6fa-8585-42ee-9fca-05cd9e667 ...
# ================================== Ai Message ==================================
#
# Based on the latest available data from Google Finance, the stock price for Microsoft (MSFT) is as follows:
#
# *   **Current Price:** $407.78
# *   **After-hours Price:** $408.65 (up 0.21%)
# *   **Market Cap:** Approximately $3.03 trillion USD
# *   **Exchange:** NASDAQ
#
# *Please note that stock prices fluctuate in real-time, and you may want to check a live financial portal for the most up-to-the-second valuation.*

# %% [markdown]
# ### Define the Web Search Tool
#
# The `tavily_search` tool uses Tavily for URL discovery, then fetches full webpage content so the agent can analyze complete sources instead of summaries.

# %%
import os
from typing import Annotated, Literal

import httpx
from langchain.tools import InjectedToolArg, tool
from markdownify import markdownify

def fetch_webpage_content(url: str, timeout: float = 10.0) -> str:
    """Fetch webpage and convert HTML to markdown."""
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    try:
        response = httpx.get(url, headers=headers, timeout=timeout)
        response.raise_for_status()
        return markdownify(response.text)
    except Exception as e:
        return f"Error fetching {url}: {e!s}"


# @tool(parse_docstring=True)
# def web_search(
#     query: str,
#     max_results: Annotated[int, InjectedToolArg] = 1,
#     topic: Annotated[
#         Literal["general", "news", "finance"], InjectedToolArg
#     ] = "general",
# ) -> str:
#     """Search the web for information on a given query.

#     Uses Tavily to discover relevant URLs, then fetches and returns full webpage content as markdown.

#     Args:
#         query: Search query to execute
#         max_results: Maximum number of results to return (default: 1)
#         topic: Topic filter - 'general', 'news', or 'finance' (default: 'general')

#     Returns:
#         Formatted search results with full webpage content
#     """
#     search_results = tavily_client.search(
#         query,
#         max_results=max_results,
#         topic=topic,
#     )
#     result_texts = []
#     for result in search_results.get("results", []):
#         url = result["url"]
#         title = result["title"]
#         content = fetch_webpage_content(url)
#         result_texts.append(f"## {title}\n**URL:** {url}\n\n{content}\n---")

#     return f"Found {len(result_texts)} result(s) for '{query}':\n\n" + "\n".join(
#         result_texts
#     )

# print("tavily_search tool defined.")

# %% [markdown]
# ### Define Prompt Templates
#
# The deep research agent uses three prompt templates:
#
# 1. **Research Workflow Instructions** — Guides the orchestrator on how to plan, delegate, synthesize, and write reports.
# 2. **Researcher Instructions** — Tells sub-agents how to conduct web searches and format findings with citations.
# 3. **Sub-Agent Delegation Instructions** — Controls how the orchestrator decomposes tasks and parallelizes sub-agent work.

# %%
RESEARCH_WORKFLOW_INSTRUCTIONS = """# Research Workflow

Follow this workflow for all research requests:

1. **Plan**: Create a todo list with write_todos to break down the research into focused tasks
2. **Save the request**: Use write_file() to save the user's research question to `/research_request.md`
3. **Research**: Delegate research tasks to sub-agents using the task() tool - ALWAYS use sub-agents for research, never conduct research yourself
4. **Synthesize**: Review all sub-agent findings and consolidate citations (each unique URL gets one number across all findings)
5. **Write Report**: Write a comprehensive final report to `/final_report.md` (see Report Writing Guidelines below)
6. **Verify**: Read `/research_request.md` and confirm you've addressed all aspects with proper citations and structure

## Research Planning Guidelines
- Batch similar research tasks into a single TODO to minimize overhead
- For simple fact-finding questions, use 1 sub-agent
- For comparisons or multi-faceted topics, delegate to multiple parallel sub-agents
- Each sub-agent should research one specific aspect and return findings

## Report Writing Guidelines

When writing the final report to `/final_report.md`, follow these structure patterns:

**For comparisons:**
1. Introduction
2. Overview of topic A
3. Overview of topic B
4. Detailed comparison
5. Conclusion

**For lists/rankings:**
Simply list items with details - no introduction needed:
1. Item 1 with explanation
2. Item 2 with explanation
3. Item 3 with explanation

**For summaries/overviews:**
1. Overview of topic
2. Key concept 1
3. Key concept 2
4. Key concept 3
5. Conclusion

**General guidelines:**
- Use clear section headings (## for sections, ### for subsections)
- Write in paragraph form by default - be text-heavy, not just bullet points
- Do NOT use self-referential language ("I found...", "I researched...")
- Write as a professional report without meta-commentary
- Each section should be comprehensive and detailed
- Use bullet points only when listing is more appropriate than prose

**Citation format:**
- Cite sources inline using [1], [2], [3] format
- Assign each unique URL a single citation number across ALL sub-agent findings
- End report with ### Sources section listing each numbered source
- Number sources sequentially without gaps (1,2,3,4...)
- Format: [1] Source Title: URL (each on separate line for proper list rendering)
- Example:

 Some important finding [1]. Another key insight [2].

 ### Sources
 [1] AI Research Paper: https://example.com/paper
 [2] Industry Analysis: https://example.com/analysis
"""

print("RESEARCH_WORKFLOW_INSTRUCTIONS defined.")

# %%
RESEARCHER_INSTRUCTIONS = """You are a research assistant conducting research on the user's input topic. For context, today's date is {date}.

Your job is to use tools to gather information about the user's input topic.
You can use the tavily_search tool to find resources that can help answer the research question.
You can call it in series or in parallel, your research is conducted in a tool-calling loop.

You have access to the tavily_search tool for conducting web searches.

Think like a human researcher with limited time. Follow these steps:

1. **Read the question carefully** - What specific information does the user need?
2. **Start with broader searches** - Use broad, comprehensive queries first
3. **After each search, pause and assess** - Do I have enough to answer? What's still missing?
4. **Execute narrower searches as you gather information** - Fill in the gaps
5. **Stop when you can answer confidently** - Don't keep searching for perfection

**Tool Call Budgets** (Prevent excessive searching):
- **Simple queries**: Use 2-3 search tool calls maximum
- **Complex queries**: Use up to 5 search tool calls maximum
- **Always stop**: After 5 search tool calls if you cannot find the right sources

**Stop Immediately When**:
- You can answer the user's question comprehensively
- You have 3+ relevant examples/sources for the question
- Your last 2 searches returned similar information

After each search, assess results before continuing: What key information did I find? What's missing? Do I have enough to answer? Should I search more or provide my answer?

When providing your findings back to the orchestrator:

1. **Structure your response**: Organize findings with clear headings and detailed explanations
2. **Cite sources inline**: Use [1], [2], [3] format when referencing information from your searches
3. **Include Sources section**: End with ### Sources listing each numbered source with title and URL

Example:
## Key Findings

Context engineering is a critical technique for AI agents [1]. Studies show that proper context management can improve performance by 40% [2].

### Sources
[1] Context Engineering Guide: https://example.com/context-guide
[2] AI Performance Study: https://example.com/study

The orchestrator will consolidate citations from all sub-agents into the final report.
"""

print("RESEARCHER_INSTRUCTIONS defined.")

# %%
SUBAGENT_DELEGATION_INSTRUCTIONS = """# Sub-Agent Research Coordination

Your role is to coordinate research by delegating tasks from your TODO list to specialized research sub-agents.

## Delegation Strategy

**DEFAULT: Start with 1 sub-agent** for most queries:
- "What is quantum computing?" -> 1 sub-agent (general overview)
- "List the top 10 coffee shops in San Francisco" -> 1 sub-agent
- "Summarize the history of the internet" -> 1 sub-agent
- "Research context engineering for AI agents" -> 1 sub-agent (covers all aspects)

**ONLY parallelize when the query EXPLICITLY requires comparison or has clearly independent aspects:**

**Explicit comparisons** -> 1 sub-agent per element:
- "Compare OpenAI vs Anthropic vs DeepMind AI safety approaches" -> 3 parallel sub-agents
- "Compare Python vs JavaScript for web development" -> 2 parallel sub-agents

**Clearly separated aspects** -> 1 sub-agent per aspect (use sparingly):
- "Research renewable energy adoption in Europe, Asia, and North America" -> 3 parallel sub-agents (geographic separation)
- Only use this pattern when aspects cannot be covered efficiently by a single comprehensive search

## Key Principles
- **Bias towards single sub-agent**: One comprehensive research task is more token-efficient than multiple narrow ones
- **Avoid premature decomposition**: Don't break "research X" into "research X overview", "research X techniques", "research X applications" - just use 1 sub-agent for all of X
- **Parallelize only for clear comparisons**: Use multiple sub-agents when comparing distinct entities or geographically separated data

## Parallel Execution Limits
- Use at most {max_concurrent_research_units} parallel sub-agents per iteration
- Make multiple task() calls in a single response to enable parallel execution
- Each sub-agent returns findings independently

## Research Limits
- Stop after {max_researcher_iterations} delegation rounds if you haven't found adequate sources
- Stop when you have sufficient information to answer comprehensively
- Bias towards focused research over exhaustive exploration"""

print("SUBAGENT_DELEGATION_INSTRUCTIONS defined.")

# %% [markdown]
# ### Create the Deep Research Agent
#
# The `create_deep_agent` function from the `deepagents` package creates the orchestrator agent with:
#
# - The self-hosted LLM model
# - The `tavily_search` tool (available to both orchestrator and sub-agents)
# - A combined system prompt (workflow + delegation instructions)
# - A research sub-agent definition with its own prompt and tools

# %%
from datetime import datetime
from deepagents import create_deep_agent

max_concurrent_research_units = 3
max_researcher_iterations = 3

current_date = datetime.now().strftime("%Y-%m-%d")

# Combine workflow + delegation instructions for the orchestrator
INSTRUCTIONS = (
    RESEARCH_WORKFLOW_INSTRUCTIONS
    + "\n\n"
    + "=" * 80
    + "\n\n"
    + SUBAGENT_DELEGATION_INSTRUCTIONS.format(
        max_concurrent_research_units=max_concurrent_research_units,
        max_researcher_iterations=max_researcher_iterations,
    )
)

# Define the research sub-agent
research_sub_agent = {
    "name": "research-agent",
    "description": "Delegate research to the sub-agent. Give one topic at a time.",
    "system_prompt": RESEARCHER_INSTRUCTIONS.format(date=current_date),
    "tools": [mcp_client],
}

# Create the deep research agent using the self-hosted LLM
agent = create_deep_agent(
    model=model,
    tools=[mcp_tools_web_search],
    system_prompt=INSTRUCTIONS,
    subagents=[research_sub_agent],
)

print("Deep Research Agent created successfully!")

# %% [markdown]
# ### Run the Deep Research Agent — Synchronous
#
# Ask the agent a research question. It will plan, delegate to sub-agents, and synthesize a report.

# %%
from langchain_core.messages import HumanMessage

result = await agent.ainvoke(
    {
        "messages": [
            HumanMessage(
                content="What are the main differences between RAG and fine-tuning for LLM applications?"
            )
        ]
    }
)

# Print the final response
for msg in result.get("messages", []):
    if hasattr(msg, "content") and msg.content:
        msg.pretty_print()

# %% [markdown]
# ### Run with Streaming
#
# Stream updates as the agent works — each step (planning, sub-agent delegation, tool calls, synthesis) is printed in real time.

# %%
async for step in agent.astream(
    {
        "messages": [
            HumanMessage(
                content="Compare Azure Container Apps vs Azure Kubernetes Service for deploying AI workloads."
            )
        ]
    },
    stream_mode="values",
):
    step["messages"][-1].pretty_print()

# %% [markdown]
# ## More Resources
#
# - [Build a Deep Research Agent](https://docs.langchain.com/oss/python/deepagents/deep-research) — official LangChain tutorial
# - [Deep Agents](https://docs.langchain.com/oss/python/deepagents) — orchestrate subagents with context isolation
# - [Subagents](https://docs.langchain.com/oss/python/deepagents/subagents) — configure subagents with different tools and prompts
# - [Deep Research Course](https://academy.langchain.com/courses/deep-research-with-langgraph) — full course on deep research with LangGraph
# - [Tavily](https://www.tavily.com/) — web search API for AI agents
# - [Full Deep Research Example on GitHub](https://github.com/langchain-ai/deepagents/tree/main/examples/deep_research)

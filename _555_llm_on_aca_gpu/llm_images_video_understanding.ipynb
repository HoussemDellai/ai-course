# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.32.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\azureuser\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\azureuser\AppData\Roaming\Python\Python313\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
aca_gemma4_31b_it_a100_fqdn = ! terraform -chdir=./infra output -raw aca_gemma4_31b_it_a100_fqdn
aca_gemma4_31b_it_a100_fqdn = aca_gemma4_31b_it_a100_fqdn.n
print("👉🏻 Gemma4 31B IT Endpoint:", aca_gemma4_31b_it_a100_fqdn)

aca_qwen_36_35b_a100_fqdn = ! terraform -chdir=infra output -raw aca_qwen_36_35b_a100_fqdn
aca_qwen_36_35b_a100_fqdn = aca_qwen_36_35b_a100_fqdn.n
print("LLM Endpoint:", aca_qwen_36_35b_a100_fqdn)

aca_gemma4_e4b_it_a100_fqdn = ! terraform -chdir=./infra output -raw aca_gemma4_e4b_it_a100_fqdn
aca_gemma4_e4b_it_a100_fqdn = aca_gemma4_e4b_it_a100_fqdn.n
print("👉🏻 Gemma4 E4B IT Endpoint:", aca_gemma4_e4b_it_a100_fqdn)
# Out:
# 👉🏻 Gemma4 31B IT Endpoint: ╷
# │ Error: Output "aca_gemma4_31b_it_a100_fqdn" not found
# │
# │ The output variable requested could not be found in the state file. If you
# │ recently added this to your configuration, be sure to run `terraform
# │ apply`, since the state won't be updated with new output variables until
# │ that command is run.
# ╵
# LLM Endpoint: qwen-3-6-35b-a100.gentlemushroom-793350b5.swedencentral.azurecontainerapps.io
# 👉🏻 Gemma4 E4B IT Endpoint: ╷
# │ Error: Output "aca_gemma4_e4b_it_a100_fqdn" not found
# │
# │ The output variable requested could not be found in the state file. If you
# │ recently added this to your configuration, be sure to run `terraform
# │ apply`, since the state won't be updated with new output variables until
# │ that command is run.
# ╵

# %%
from openai import OpenAI

client = OpenAI(
    base_url=f"http://{aca_qwen_36_35b_a100_fqdn}/v1",
    api_key="EMPTY"
)

print(client.models.list())

response = client.chat.completions.create(
    model="Qwen/Qwen3.6-35B-A3B", # "google/gemma-4-31B-it",
    messages=[
        {"role": "user", "content": "Tell me about yourself."}
    ],
    max_tokens=512,
    temperature=1.0
)

print(response.choices[0].message.content)
# Out:
# SyncPage[Model](data=[Model(id='Qwen/Qwen3.6-35B-A3B', created=1780143204, object='model', owned_by='vllm', root='Qwen/Qwen3.6-35B-A3B', parent=None, max_model_len=65536, permission=[{'id': 'modelperm-95c9d194594d9748', 'object': 'model_permission', 'created': 1780143204, 'allow_create_engine': False, 'allow_sampling': True, 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True, 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking': False}])], object='list')
#
#
# I'm Qwen, a large language model developed by Alibaba Group's Tongyi Lab. I'm designed to be a clear, thoughtful, and practical AI thinking partner. I can help you reason through complex problems, write and debug code, analyze documents, brainstorm ideas, translate across dozens of languages, and more. My goal is to adapt to your needs and make your work or learning easier and more efficient.
#
# What can I help you with today?

# %% [markdown]
# ## Image Understanding
#
# Gemma 4 natively understands images via its custom vision encoder with configurable resolution (utilizing native vision blocks).
# Let's test with this sample image.
#
# ![Image](https://raw.githubusercontent.com/HoussemDellai/ai-course/refs/heads/main/555_comfyui_on_aca/images/resources.png)

# %%
from openai import OpenAI

client = OpenAI(base_url=f"http://{aca_qwen_36_35b_a100_fqdn}/v1", api_key="EMPTY")
# client = OpenAI(base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1", api_key="EMPTY")

response = client.chat.completions.create(
    model="Qwen/Qwen3.6-35B-A3B", # "google/gemma-4-31B-it",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://raw.githubusercontent.com/HoussemDellai/ai-course/refs/heads/main/555_comfyui_on_aca/images/resources.png"
                    },
                },
                {"type": "text", "text": "Describe this image in detail."},
            ],
        }
    ],
    max_tokens=60000,
    temperature=1.0,
)

print(response.choices[0].message.content)
# Out:
# This image displays a screenshot of a resource list from a cloud computing dashboard, most likely the Microsoft Azure portal, shown in a dark mode interface. The view is a table with two primary columns: "Name" (sorted in ascending order, indicated by an upward arrow) and "Type."
#
# Each row represents a specific cloud resource. From left to right, each entry features a checkbox, a specific icon representing the resource type, the resource name in blue hyperlink text, an ellipsis menu ("..."), and the full resource type.
#
# The specific resources listed from top to bottom are:
#
# 1.  **aca-debugger**: Type is "Container App" (Icon is purple).
# 2.  **aca-env-gpu-nvidia**: Type is "Container Apps ..." (The text is truncated).
# 3.  **aca-job-download-models**: Type is "Container App J..." (The text is truncated).
# 4.  **comfyui-cu126-a100**: Type is "Container App". The name suggests a ComfyUI environment using CUDA 12.6 and an A100 GPU.
# 5.  **comfyui-cu126-t4**: Type is "Container App". Similar to the above, likely using a T4 GPU.
# 6.  **nic-pe-storage-account**: Type is "Network Interfa..." (Truncated, likely Network Interface). The icon is a green network card.
# 7.  **pe-storage-account**: Type is "Private endpoint". The icon shows blue connected nodes.
# 8.  **privatelink.file.core.windows.net**: Type is "Private DNS zone". The icon is a blue circle labeled "DNS".
# 9.  **storage4comfyui4aca**: Type is "Storage account". The icon resembles a server or database stack.
# 10. **vnet-aca**: Type is "Virtual network". The icon shows connected green nodes.
#
# The naming conventions suggest this is an infrastructure setup for hosting AI workloads (specifically ComfyUI) using Azure Container Apps, involving GPU resources, storage accounts, and private networking configurations.

# %% [markdown]
# ## Video Understanding
#
# Video understanding is supported via a custom processing pipeline (available in this vLLM branch) that extracts video frames and pairs them with text prompts for the vision tower.
# Make sure to launch the container with the `--limit-mm-per-prompt` flag to allow video inputs (e.g. `--limit-mm-per-prompt video=1` to allow 1 video input per prompt). In this example, this was already done in the Terraform template.

# %%
from openai import OpenAI

client = OpenAI(base_url=f"http://{aca_qwen_36_35b_a100_fqdn}/v1", api_key="EMPTY")
# client = OpenAI(base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1", api_key="EMPTY")

response = client.chat.completions.create(
    model="Qwen/Qwen3.6-35B-A3B",
    # model="google/gemma-4-31B-it",
    # model="google/gemma-4-E2B-it",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "video_url",
                    "video_url": {
                        "url": "https://storage4swc.blob.core.windows.net/llm-videos/Google-I-O-2026-keynote-in-35-minutes_1080p.mp4?sp=r&st=2026-05-21T04:03:50Z&se=2027-01-31T13:18:50Z&spr=https&sv=2026-02-06&sr=b&sig=Db232%2BMTuf%2B2FWNLVNU%2BPwUhNj7%2F5N4pE8GBINzcAA8%3D"
                    },
                },
                {"type": "text", "text": "Summarize what happens in this video."},
            ],
        }
    ],
    max_tokens=60000, # 8192,  # 1024
    temperature=1.0,
    stream=True
)

for chunk in response:
    print(chunk.choices[0].delta.content, end="", flush=True)

# print("Output tokens: ", response.usage.completion_tokens)

# print(response.choices[0].message.content)
# Out:
# ...
#
# The video is a recording of a Google I/O keynote presentation hosted by CEO Sundar Pichai. Here is a summary of the key announcements and demonstrations:
#
# *   **Introduction to Gemini 2.0:** Pichai unveils the next generation of Google's AI model, Gemini 2.0. He introduces two new versions:
#     *   **Gemini 2.0 Flash:** Described as an "agentic" AI model. It is designed to not just answer questions but to take action, such as planning a trip, booking flights, and ordering groceries in a single flow.
#     *   **Gemini 2.5 Pro:** A high-performance model capable of reasoning through complex tasks. It features a massive 1-million-token context window, allowing it to process and analyze extremely long documents or hour-long videos.
# *   **Reasoning and "Chain of Thought":** The presentation highlights the model's ability to think through problems step-by-step. Live demos show the AI solving complex math and science problems, explaining its reasoning process as it goes.
# *   **Creative Tools:**
#     *   **Gemini Spark:** A new experimental app is announced that allows users to create images, stories, and videos using AI.
#     *   **Video Generation:** The keynote demonstrates capabilities for generating video from text and images, including "VideoFX" features that allow users to edit videos by describing changes in natural language (e.g., "make it night").
# *   **Search and Smart Actions:** Google Search is getting a major upgrade with "Smart Actions." Users can now perform tasks like booking a restaurant or buying tickets directly within the search results interface without leaving the page.
# *   **Productivity Updates:** New AI features are introduced for Google Workspace.
#     *   **Docs Live:** A feature that listens to a meeting and automatically generates a document with key points and action items.
#     *   **Gmail & Docs:** Updates to "Compose" and "Reply" features, allowing for more nuanced and context-aware writing assistance.
# *   **Hardware Announcements:**
#     *   **Audio Glasses:** A new pair of smart glasses is announced in collaboration with Ray-Ban. These glasses feature audio capabilities and a camera for AI interactions.
#     *   **Intelligent Eyewear:** Pichai also reveals a concept for future "intelligent eyewear," showing a prototype of AR glasses that can overlay information on the real world.
